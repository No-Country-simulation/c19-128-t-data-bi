# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/NoxiePC/Pictures/DATA/TotalFeatures-ISCXFlowMeter.csv')
data.head()
# Out:
#    duration  total_fpackets  total_bpackets  total_fpktl  total_bpktl  \
# 0   1020586             668            1641        35692      2276876
# 1     80794               1               1           75          124
# 2       998               3               0          187            0
# 3    189868               9               9         1448         6200
# 4    110577               4               6          528         1422
#
#    min_fpktl  min_bpktl  max_fpktl  max_bpktl  mean_fpktl  ...  mean_idle  \
# 0         52         52        679       1390   53.431138  ...        0.0
# 1         75        124         75        124   75.000000  ...        0.0
# 2         52         -1         83         -1   62.333333  ...        0.0
# 3         52         52        706       1390  160.888889  ...        0.0
# 4         52         52        331       1005  132.000000  ...        0.0
#
#    max_idle  std_idle  FFNEPD  Init_Win_bytes_forward  \
# ...

# %%
data.dtypes
# Out:
# duration                    int64
# total_fpackets              int64
# total_bpackets              int64
# total_fpktl                 int64
# total_bpktl                 int64
#                             ...
# Init_Win_bytes_backward     int64
# RRT_samples_clnt            int64
# Act_data_pkt_forward        int64
# min_seg_size_forward        int64
# calss                      object
# Length: 80, dtype: object

# %%
data.shape
# Out:
# (631955, 80)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631955 entries, 0 to 631954
# Data columns (total 80 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration                 631955 non-null  int64
#  1   total_fpackets           631955 non-null  int64
#  2   total_bpackets           631955 non-null  int64
#  3   total_fpktl              631955 non-null  int64
#  4   total_bpktl              631955 non-null  int64
#  5   min_fpktl                631955 non-null  int64
#  6   min_bpktl                631955 non-null  int64
#  7   max_fpktl                631955 non-null  int64
#  8   max_bpktl                631955 non-null  int64
#  9   mean_fpktl               631955 non-null  float64
#  10  mean_bpktl               631955 non-null  float64
#  11  std_fpktl                631955 non-null  float64
#  12  std_bpktl                631955 non-null  float64
# ...

# %%
data.describe()
# Out:
#            duration  total_fpackets  total_bpackets   total_fpktl  \
# count  6.319550e+05   631955.000000   631955.000000  6.319550e+05
# mean   2.195245e+07        6.728514       10.431934  9.540172e+02
# std    1.900578e+08      174.161354      349.424019  8.235040e+04
# min   -1.800000e+01        0.000000        0.000000  0.000000e+00
# 25%    0.000000e+00        1.000000        0.000000  6.900000e+01
# 50%    2.445000e+04        1.000000        0.000000  1.840000e+02
# 75%    1.759751e+06        3.000000        1.000000  4.270000e+02
# max    4.431076e+10    48255.000000    74768.000000  4.049644e+07
#
#         total_bpktl      min_fpktl      min_bpktl      max_fpktl  \
# count  6.319550e+05  631955.000000  631955.000000  631955.000000
# mean   1.206042e+04     141.475727      44.357688     263.675901
# std    4.824716e+05     157.680880      89.099554     289.644383
# min    0.000000e+00      -1.000000      -1.000000      -1.000000
# ...

# %%
data.columns
# Out:
# Index(['duration', 'total_fpackets', 'total_bpackets', 'total_fpktl',
#        'total_bpktl', 'min_fpktl', 'min_bpktl', 'max_fpktl', 'max_bpktl',
#        'mean_fpktl', 'mean_bpktl', 'std_fpktl', 'std_bpktl', 'total_fiat',
#        'total_biat', 'min_fiat', 'min_biat', 'max_fiat', 'max_biat',
#        'mean_fiat', 'mean_biat', 'std_fiat', 'std_biat', 'fpsh_cnt',
#        'bpsh_cnt', 'furg_cnt', 'burg_cnt', 'total_fhlen', 'total_bhlen',
#        'fPktsPerSecond', 'bPktsPerSecond', 'flowPktsPerSecond',
#        'flowBytesPerSecond', 'min_flowpktl', 'max_flowpktl', 'mean_flowpktl',
#        'std_flowpktl', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
#        'std_flowiat', 'flow_fin', 'flow_syn', 'flow_rst', 'flow_psh',
#        'flow_ack', 'flow_urg', 'flow_cwr', 'flow_ece', 'downUpRatio',
#        'avgPacketSize', 'fAvgSegmentSize', 'fHeaderBytes', 'fAvgBytesPerBulk',
#        'fAvgPacketsPerBulk', 'fAvgBulkRate', 'bVarianceDataBytes',
# ...

# %%
# Analizaremos si hay valores faltantes en el dataset.

data.isnull().sum()
# Out:
# duration                   0
# total_fpackets             0
# total_bpackets             0
# total_fpktl                0
# total_bpktl                0
#                           ..
# Init_Win_bytes_backward    0
# RRT_samples_clnt           0
# Act_data_pkt_forward       0
# min_seg_size_forward       0
# calss                      0
# Length: 80, dtype: int64

# %%
# Veremos los distintos tipos de clase que hay

tipos_clase = data['calss'].unique()
tipos_clase
# Out:
# array(['benign', 'asware', 'GeneralMalware'], dtype=object)

# %%
conteo_clases = data['calss'].value_counts()
print(conteo_clases)
# Out:
# calss
# benign            471597
# asware            155613
# GeneralMalware      4745
# Name: count, dtype: int64

# %%
# Convertiremos las clases a valores númericos para construir correlation matrix

from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['class_numerica'] = le.fit_transform(data['calss'])

# %%
print(data['class_numerica'].unique())
# Out:
# [2 1 0]

# %%
import matplotlib.pyplot as plt
# Seleccionar las características numéricas para el análisis de correlación
columnas_numericas = ['duration','total_fpackets', 'total_bpackets', 'total_fpktl', 'total_bpktl', 'mean_fpktl', 'mean_bpktl', 'class_numerica']
df_numeric = data[columnas_numericas]

# Calcular la matriz de correlación
matriz_correlacion = df_numeric.corr()

# Visualizar la matriz de correlación como un mapa de calor
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de correlación')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Histograma para la duración

plt.boxplot(data['duration'])
plt.xlabel('Duración')
plt.ylabel('Frecuencia')
plt.title('Histograma de duración')
plt.show()

# %%
clases = ['benigno', 'software publicitario', 'software malicioso']
counts = [471597, 155613, 4745]

plt.figure(figsize=(10, 6))
plt.bar(clases, counts, color='blue', alpha=0.7)

plt.title('conteo de instancias por clase')
plt.xlabel('Clase')
plt.ylabel('Conteo de instancias')
plt.grid(True)
plt.show()

# %%
# analizaremos los outliers

columna_1 = data['duration']

Q1 = columna_1.quantile(0.25)
Q3 = columna_1.quantile(0.75)

IQR = Q3 - Q1

outliers = (columna_1 < Q1 - 1.5 * IQR) | (columna_1 > Q3 + 1.5 * IQR)

print(columna_1[outliers])
# Out:
# 11         5008461
# 12        59125997
# 19        48236088
# 21        46176642
# 34        59999002
#             ...
# 631947    50634716
# 631951    50240627
# 631952    35471450
# 631953    41713629
# 631954    50110119
# Name: duration, Length: 138588, dtype: int64

# %%
# valores únicos

valores_unicos = data['duration'].unique()
valores_unicos
# Out:
# array([ 1020586,    80794,      998, ..., 35471450, 41713629, 50110119],
#       dtype=int64)

# %%
# Feature selection

from sklearn.ensemble import RandomForestClassifier

X = data.drop('calss', axis=1)
y = data['calss']

rf = RandomForestClassifier()
rf.fit(X,y)

feature_importances = rf.feature_importances_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Obtener los nombres de las columnas de X (características)
feature_names = X.columns

# Obtener la importancia de las características del modelo
feature_importances = rf.feature_importances_

# Crear un DataFrame para mostrar las importancias junto con los nombres de las características
feature_importances_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Ordenar por importancia descendente
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Visualizar las importancias de las características
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importances_df.head(20))
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 20 Feature Importances')
plt.show()

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 10))
plot_tree(rf.estimators_[0], feature_names=feature_names, filled=True, max_depth=3)
plt.title('Example Decision Tree')
plt.show()
